# %%
result = {0: {'out': {'out3': 0.842, 'out2': 0.997, 'out1': 0.902, 'out0': 0.875},
  'brain': {'mid1out3': ['mid1', 'out3', 0.8382115061803754],
   'in0mid0': ['in0', 'mid0', -2.100289943537311],
   'in0out2': ['in0', 'out2', 2.962185258660156],
   'in1mid0': ['in1', 'mid0', 3.2203876087288266],
   'mid1out1': ['mid1', 'out1', 1.1071570273157332],
   'mid1mid1': ['mid1', 'mid1', -2.1820845414314056],
   'mid1out0': ['mid1', 'out0', 2.803601403937128]},
  'in': ['in0', 'in1'],
  'genome': ['ad889ad2',
   '50444334',
   '2cd2dec8',
   '412ce70b',
   'd7ae0866',
   'ab7345d2',
   '87bda36d',
   '9b94d9b5'],
  'position': [[6, 7]]},
 1: {'out': {'out4': 0.087, 'out0': 0.598},
  'brain': {'mid0mid1': ['mid0', 'mid1', 3.549885548603693],
   'in1out4': ['in1', 'out4', -1.1752784983976805],
   'mid1out0': ['mid1', 'out0', 0.19948115367007477],
   'in0mid1': ['in0', 'mid1', -3.0537463757057837],
   'mid0out4': ['mid0', 'out4', 2.127514115672211]},
  'in': ['in1', 'in0'],
  'genome': ['9401f196',
   '63de58c7',
   'c38f8662',
   '4265a4a1',
   '682d61b6',
   '957637a3',
   'dca7c413',
   '1de3259b'],
  'position': [[1, 6]]},
 2: {'out': {'out4': 0.0, 'out2': 0.698, 'out0': 0.639},
  'brain': {'in0mid0': ['in0', 'mid0', -2.9732946741950252],
   'mid0mid0': ['mid0', 'mid0', -0.7621547382878071],
   'in0out4': ['in0', 'out4', -3.972165420418129],
   'in0out2': ['in0', 'out2', 0.418617427132611],
   'in1out0': ['in1', 'out0', 0.2850602777353884],
   'mid1out3': ['mid1', 'out3', 0.2799328551808332],
   'mid1mid0': ['mid1', 'mid0', -1.665924004272852]},
  'in': ['in0', 'in1'],
  'genome': ['3e185f23',
   'b2421863',
   '14e37f19',
   '6e9b8d65',
   '07fd7858',
   'df8388f5',
   '9b64354e',
   '39ad891f'],
  'position': [[0, 2]]},
 4: {'out': {'out4': 0.0, 'out0': 1.0, 'out2': 0.616},
  'brain': {'mid1mid0': ['mid1', 'mid0', 2.22115061803754],
   'in0out4': ['in0', 'out4', -1.140607355409736],
   'in1out0': ['in1', 'out0', 3.787944452922326],
   'in1out2': ['in1', 'out2', 1.7862963528155043],
   'mid0out0': ['mid0', 'out0', 2.7802838394628413],
   'mid0out4': ['mid0', 'out4', -2.874652830764535],
   'mid0mid0': ['mid0', 'mid0', -1.4952540820998017],
   'in0out2': ['in0', 'out2', -1.5508011597741493]},
  'in': ['in0', 'in1'],
  'genome': ['bb56c712',
   '3ce8247f',
   '55a3f934',
   '47d7b928',
   'ecdad8f6',
   'b4845bfb',
   '84362fd8',
   '5696319f'],
  'position': [[1, 8]]},
 5: {'out': {'out1': 0.999, 'out2': 0.943, 'out3': 0.501},
  'brain': {'mid1out2': ['mid1', 'out2', -0.0888753242789562],
   'in1mid0': ['in1', 'mid0', -1.587181443613612],
   'in0out1': ['in0', 'out1', 3.6929650541736607],
   'in1out2': ['in1', 'out2', 1.401129253776896],
   'mid0out3': ['mid0', 'out3', -2.030215168625057]},
  'in': ['in1', 'in0'],
  'genome': ['bbd202d8',
   '473cc0ac',
   '42e5f62a',
   '3774a479',
   '7fcdacd5',
   '272e32c9',
   'a2c92d1d',
   'b0a140f6'],
  'position': [[4, 1]]},
 6: {'out': {'out3': 0.855,
   'out4': 0.383,
   'out2': 1.0,
   'out1': 0.996,
   'out0': 0.001},
  'brain': {'in0out3': ['in0', 'out3', 0.21071265069433848],
   'mid1out4': ['mid1', 'out4', -0.23891347474439187],
   'in1out2': ['in1', 'out2', 3.8045475354799327],
   'mid0out3': ['mid0', 'out3', 0.675476880817946],
   'mid0mid1': ['mid0', 'mid1', 1.470593621242179],
   'in0mid0': ['in0', 'mid0', -0.43265679841294064],
   'in1out1': ['in1', 'out1', 2.7121623683808944],
   'in0out0': ['in0', 'out0', -3.549275141156722]},
  'in': ['in0', 'in1'],
  'genome': ['7eba86be',
   'e3de07a5',
   '4fd2f9bc',
   'babf959d',
   'fa65af0e',
   '4a4e0dd8',
   '71a9d6c8',
   '42e97191'],
  'position': [[3, 8]]},
 7: {'out': {'out0': 0.156, 'out3': 0.523, 'out1': 0.881},
  'brain': {'mid0mid1': ['mid0', 'mid1', -2.2892720891194873],
   'in0out0': ['in0', 'out0', -1.6935144208759347],
   'in0mid1': ['in0', 'mid1', 2.2647337097512588],
   'mid0mid0': ['mid0', 'mid0', 2.9240958339691745],
   'mid1out3': ['mid1', 'out3', -2.493514420875935],
   'in1out0': ['in1', 'out0', 0.85005341065161],
   'mid0out1': ['mid0', 'out1', 3.9289485731725926]},
  'in': ['in0', 'in1'],
  'genome': ['96054940',
   '00aee950',
   '22853630',
   '6015c877',
   '800add90',
   'd5884fc9',
   '3fc69b33',
   '80dbfdb7'],
  'position': [[1, 0]]},
 8: {'out': {'out0': 0.02, 'out3': 0.005, 'out4': 1.0},
  'brain': {'mid0mid1': ['mid0', 'mid1', -2.666870135815657],
   'in1out0': ['in1', 'out0', -1.9396307034945826],
   'in1out3': ['in1', 'out3', -2.687501907523272],
   'in1out4': ['in1', 'out4', 3.7770792003662446],
   'in1mid1': ['in1', 'mid1', -0.13087135663055088],
   'mid1out4': ['mid1', 'out4', 1.1567221120097666],
   'in0mid1': ['in0', 'mid1', 0.2789562032656798],
   'mid0out2': ['mid0', 'out2', -3.9316343659392645]},
  'in': ['in1', 'in0'],
  'genome': ['8c095555',
   '6be93e10',
   '79ab55fe',
   '0de8f8db',
   '3b530430',
   'e7fca503',
   '026188ed',
   '80e17dcd'],
  'position': [[2, 0]]},
 9: {'out': {'out2': 0.978, 'out1': 0.027},
  'brain': {'in1mid0': ['in1', 'mid0', 1.4753547993285518],
   'mid0mid0': ['mid0', 'mid0', -3.0303067297421027],
   'in0out2': ['in0', 'out2', 1.8929955745460094],
   'mid1out3': ['mid1', 'out3', -3.6546314665038913],
   'mid1out4': ['mid1', 'out4', 0.5715855333435068],
   'mid1mid0': ['mid1', 'mid0', 0.3862658324431558],
   'in1out1': ['in1', 'out1', -1.7928887532427895]},
  'in': ['in1', 'in0'],
  'genome': ['4356af35',
   'a04060f6',
   '54ebbc92',
   '0a33c043',
   '8d9c74f0',
   'e789924a',
   'd1288c5c',
   '7595395e'],
  'position': [[3, 1]]},
 10: {'out': {'out3': 0.999, 'out4': 0.001},
  'brain': {'in0mid0': ['in0', 'mid0', -0.7997558370212117],
   'mid1out4': ['mid1', 'out4', 1.3673126812147107],
   'mid0out3': ['mid0', 'out3', 0.8393102395849229],
   'in0out3': ['in0', 'out3', 2.7874866473370976],
   'in1mid0': ['in1', 'mid0', 2.2195635586754157],
   'mid1out2': ['mid1', 'out2', 3.0737677399664274],
   'in1out4': ['in1', 'out4', -3.2540820998016176]},
  'in': ['in0', 'in1'],
  'genome': ['36601997',
   'b1acabc0',
   'b2d89adb',
   '1ebad931',
   '753ac705',
   '97dc7de1',
   '8591e25a',
   '2de3681f'],
  'position': [[9, 5]]}}

# %%
result[0]
# Out:
# {'out': {'out3': 0.842, 'out2': 0.997, 'out1': 0.902, 'out0': 0.875},
#  'brain': {'mid1out3': ['mid1', 'out3', 0.8382115061803754],
#   'in0mid0': ['in0', 'mid0', -2.100289943537311],
#   'in0out2': ['in0', 'out2', 2.962185258660156],
#   'in1mid0': ['in1', 'mid0', 3.2203876087288266],
#   'mid1out1': ['mid1', 'out1', 1.1071570273157332],
#   'mid1mid1': ['mid1', 'mid1', -2.1820845414314056],
#   'mid1out0': ['mid1', 'out0', 2.803601403937128]},
#  'in': ['in0', 'in1'],
#  'genome': ['ad889ad2',
#   '50444334',
#   '2cd2dec8',
#   '412ce70b',
#   'd7ae0866',
#   'ab7345d2',
#   '87bda36d',
#   '9b94d9b5'],
#  'position': [[6, 7]]}

# %%
import random

# %%
out4 = {f'out{str(weight)}': random.random() for weight in range(4)}
out4
# Out:
# {'out0': 0.13543604364233797,
#  'out1': 0.669931486524111,
#  'out2': 0.652201657546484,
#  'out3': 0.9747169935677937}

# %%
set(result[0]['out'])
# Out:
# {'out0', 'out1', 'out2', 'out3'}

# %%
if 'out4' in result[0]['out']:
    out4 = {f'out{str(weight)}': random.random() for weight in range(4)}
else:
